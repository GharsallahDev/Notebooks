# %%
import os
import gc
import shutil
import json
import tensorflow as tf
import random
import numpy as np
from PIL import Image, ImageOps, ImageEnhance, UnidentifiedImageError
from collections import defaultdict
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split

# %%
if not os.path.exists('/kaggle/working/dataset'):
    os.makedirs('/kaggle/working/dataset')

for image_file in os.listdir('/kaggle/input/varroa-dataset/images'):
    shutil.copy(os.path.join('/kaggle/input/varroa-dataset/images', image_file), '/kaggle/working/dataset')

shutil.copy('/kaggle/input/varroa-dataset/_annotations.coco.json', '/kaggle/working/_annotations.coco.json')
# Out:
# '/kaggle/working/_annotations.coco.json'

# %%
# Setup paths
dataset_dir = "/kaggle/working/dataset"
annotations_path = "/kaggle/working/_annotations.coco.json"

with open(annotations_path, 'r') as f:
    coco_data = json.load(f)

bad_images = []
extra_images_in_dataset = set()
valid_image_ids = set()
bbox_issues = 0

image_info = {}
for image in coco_data['images']:
    image_path = os.path.join(dataset_dir, image['file_name'])
    image_id = image['id']
    try:
        with Image.open(image_path) as img:
            img.verify()
            image_info[image_id] = {'file_name': image['file_name'], 'width': img.width, 'height': img.height}
            valid_image_ids.add(image_id)
    except Exception as e:
        print(f"Removing bad image: {image['file_name']} due to error: {e}")
        bad_images.append(image_id)
        if os.path.exists(image_path):
            os.remove(image_path)

dataset_images = set(os.listdir(dataset_dir))
annotated_image_filenames = {info['file_name'] for info in image_info.values()}
extra_images_in_dataset = dataset_images - annotated_image_filenames

for image_filename in extra_images_in_dataset:
    os.remove(os.path.join(dataset_dir, image_filename))

for annotation in coco_data['annotations']:
    if annotation['image_id'] not in valid_image_ids:
        continue
    bbox = annotation['bbox']
    img_info = image_info[annotation['image_id']]
    if bbox[0] < 0 or bbox[1] < 0 or (bbox[0] + bbox[2]) > img_info['width'] or (bbox[1] + bbox[3]) > img_info['height']:
        bbox_issues += 1
        bad_images.append(annotation['image_id'])

coco_data['images'] = [img for img in coco_data['images'] if img['id'] not in bad_images]
coco_data['annotations'] = [anno for anno in coco_data['annotations'] if anno['image_id'] not in bad_images and anno['image_id'] in valid_image_ids]

with open(annotations_path, 'w') as f:
    json.dump(coco_data, f)

print(f"Removed {len(bad_images)} bad images and {bbox_issues} annotations with invalid bounding boxes.")
print(f"Deleted {len(extra_images_in_dataset)} extra images from dataset folder.")
print("Updated annotations file with corrections.")
# Out:
# Removing bad image: 2017-09-20_19-24-55-mp4-bee_id_3849-28485-1_png_jpg.rf.02aa0aa5986faba3a3b79f46fb5a39fa.jpg due to error: cannot identify image file '/kaggle/working/dataset/2017-09-20_19-24-55-mp4-bee_id_3849-28485-1_png_jpg.rf.02aa0aa5986faba3a3b79f46fb5a39fa.jpg'
# Removing bad image: 2017-09-20_19-24-55-mp4-bee_id_4242-39465-1_png_jpg.rf.0ba1935457ff336b8bde1d1fce8d3524.jpg due to error: cannot identify image file '/kaggle/working/dataset/2017-09-20_19-24-55-mp4-bee_id_4242-39465-1_png_jpg.rf.0ba1935457ff336b8bde1d1fce8d3524.jpg'
# Removing bad image: 2017-09-20_19-24-55-mp4-bee_id_3679-24315-1_png_jpg.rf.021a960da724e643dc19589ef89f73f2.jpg due to error: cannot identify image file '/kaggle/working/dataset/2017-09-20_19-24-55-mp4-bee_id_3679-24315-1_png_jpg.rf.021a960da724e643dc19589ef89f73f2.jpg'
# Removing bad image: 2017-09-20_19-24-55-mp4-bee_id_4993-60795-1_png_jpg.rf.00f4b13659501d4e68f82d079483bb13.jpg due to error: cannot identify image file '/kaggle/working/dataset/2017-09-20_19-24-55-mp4-bee_id_4993-60795-1_png_jpg.rf.00f4b13659501d4e68f82d079483bb13.jpg'
# Removing bad image: 2017-09-20_19-24-55-mp4-bee_id_
# Removing bad image: 360_F_451655639_yIfErDNcocOtJutuWBwA8ffjun218W6z_jpg.rf.4f40d892ff4ed21a9f2ee119d09de886.jpg due to error: cannot identify image file '/kaggle/working/dataset/360_F_451655639_yIfErDNcocOtJutuWBwA8ffjun218W6z_jpg.rf.4f40d892ff4ed21a9f2ee119d09de886.jpg'
# Removing bad image: 360_F_425405391_me1oSI3bmjxjg3DUhesnjCcRzs1268Sj_jpg.rf.6603441114a54d75a81bd1b4551b9717.jpg due to error: cannot identify image file '/kaggle/working/dataset/360_F_425405391_me1oSI3bmjxjg3DUhesnjCcRzs1268Sj_jpg.rf.6603441114a54d75a81bd1b4551b9717.jpg'
# Removing bad image: 500_F_296880854_VuiwUi60cxbS7uBBxjXFw0slaoAKshwE_jpg.rf.9a7a507f634963af5347adfc83446097.jpg due to error: cannot identify image file '/kaggle/working/dataset/500_F_296880854_VuiwUi60cxbS7uBBxjXFw0slaoAKshwE_jpg.rf.9a7a507f634963af5347adfc83446097.jpg'
# Removing bad image: 360_F_509553993_4VVKWGmU0kAFEKK22i3s5YCc988tahSZ_jpg.rf.aba75a7f5e2ef4613da3143f1f9c6b72.jpg due to error: cannot identify image file '/kaggle/working/dataset/360_F_509553993_4VVKWGmU0kAFEKK22i3s5YCc988tahSZ_jpg.rf.aba75a7f5e2ef4613da3143f1f9c6b72.jpg'
# Removing bad image: 500_F_169615443_d6LoZxuyoAJ5Wb1LaRqkznGmtxjJ0NeT_jpg.rf.d9502d5d3051e00377639f2539f73e74.jpg due to error: cannot identify image file '/kaggle/working/dataset/500_F_169615443_d6LoZxuyoAJ5Wb1LaRqkznGmtxjJ0NeT_jpg.rf.d9502d5d3051e00377639f2539f73e74.jpg'
# Removing bad image: 500_F_296883185_SBrcmyfxQpimNU9ehPhbj49B0j68xU0F_jpg.rf.db397011b036eb87620d2a39b029c7e7.jpg due to error: cannot identify image file '/kaggle/working/dataset/500_F_296883185_SBrcmyfxQpimNU9ehPhbj49B0j68xU0F_jpg.rf.db397011b036eb87620d2a39b029c7e7.jpg'
# Removing bad image: 360_F_108808088_0A7a0GQ5i97pjgo0rMpjOPXf5BvF21vt_jpg.rf.f2abe18acbd18f29ee676c80354c2885.jpg due to error: cannot identify image file '/kaggle/working/dataset/360_F_108808088_0A7a0GQ5i97pjgo0rMpjOPXf5BvF21vt_jpg.rf.f2abe18acbd18f29ee676c80354c2885.jpg'
# Removed 25913 bad images and 22198 annotations with invalid bounding boxes.
# Deleted 4776 extra images from dataset folder.
# Updated annotations file with corrections.

# %%
# !pip install opencv-python
# !pip install imgaug>=0.4.0
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from opencv-python) (1.26.4)

# %%
coco_dataset_resize_dir = '/kaggle/working/coco_dataset_resize'
if not os.path.exists(coco_dataset_resize_dir):
    os.mkdir(coco_dataset_resize_dir)

# %%
shutil.copy("/kaggle/input/coco-resize/script.py","/kaggle/working/coco_dataset_resize/script.py")
# Out:
# '/kaggle/working/coco_dataset_resize/script.py'

# %%
# %cd /kaggle/working/coco_dataset_resize
# Out:
# /kaggle/working/coco_dataset_resize

# %%
# !python script.py --images_dir="/kaggle/working/dataset" --annotations_file="/kaggle/working/_annotations.coco.json" --image_width=512 --image_height=512 --output_ann_file="/kaggle/working/resized_annotations.coco.json" --output_img_dir="/kaggle/working/resized_dataset"
# Out:
# Loading annotations file...
# Annotations file loaded.
# Building dictionnaries...
# Dictionnaries built.
# Writing modified annotations to file...
# Finished.

# %%
dataset_dir = "/kaggle/working/resized_dataset"
annotations_path = "/kaggle/working/resized_annotations.coco.json"

with open(annotations_path, 'r') as f:
    coco_data = json.load(f)

image_info = {image['id']: {'file_name': image['file_name'], 'width': image['width'], 'height': image['height']} for image in coco_data['images']}

bbox_issues = 0
missing_images = 0

for annotation in coco_data['annotations']:
    image_id = annotation['image_id']
    
    if image_id not in image_info:
        missing_images += 1
        continue 

    bbox = annotation['bbox']
    image_width = image_info[image_id]['width']
    image_height = image_info[image_id]['height']

    x, y, width, height = bbox

    if x < 0 or y < 0 or (x + width) > image_width or (y + height) > image_height:
        bbox_issues += 1

print(f"Total bounding box issues detected: {bbox_issues}.")
print(f"Total missing images referenced in annotations: {missing_images}.")
# Out:
# Total bounding box issues detected: 0.
# Total missing images referenced in annotations: 0.

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
dataset_dir = "/kaggle/working/resized_dataset"
annotations_path = "/kaggle/working/resized_annotations.coco.json"

train_dir = "/kaggle/working/train"
val_dir = "/kaggle/working/val"
test_dir = "/kaggle/working/test"

with open(annotations_path) as f:
    coco_data = json.load(f)

trainval_images, test_images = train_test_split(coco_data['images'], test_size=0.1, random_state=42)
train_images, val_images = train_test_split(trainval_images, test_size=0.222, random_state=42)

def filter_annotations(annotations, images):
    image_ids = set(img['id'] for img in images)
    return [anno for anno in annotations if anno['image_id'] in image_ids]

train_annotations = filter_annotations(coco_data['annotations'], train_images)
val_annotations = filter_annotations(coco_data['annotations'], val_images)
test_annotations = filter_annotations(coco_data['annotations'], test_images)

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

def move_images(image_list, target_dir):
    for image in image_list:
        source_path = os.path.join(dataset_dir, image['file_name'])
        target_path = os.path.join(target_dir, image['file_name'])
        shutil.move(source_path, target_path)

move_images(train_images, train_dir)
move_images(val_images, val_dir)
move_images(test_images, test_dir)

for name, subset, images in zip(['train', 'val', 'test'], 
                                [train_annotations, val_annotations, test_annotations], 
                                [train_images, val_images, test_images]):
    subset_path = f"/kaggle/working/{name}_annotations.coco.json"
    with open(subset_path, 'w') as f:
        json.dump({'images': images, 'annotations': subset, 'categories': coco_data['categories']}, f)
    print(f"Saved {name} annotations to {subset_path}")
# Out:
# Saved train annotations to /kaggle/working/train_annotations.coco.json
# Saved val annotations to /kaggle/working/val_annotations.coco.json
# Saved test annotations to /kaggle/working/test_annotations.coco.json

# %%
sets = ['train', 'val', 'test']
base_dir = "/kaggle/working"
annotation_paths = {s: os.path.join(base_dir, f"{s}_annotations.coco.json") for s in sets}
image_dirs = {s: os.path.join(base_dir, s) for s in sets}

def load_coco_data(annotation_path):
    with open(annotation_path, 'r') as file:
        return json.load(file)

def verify_dataset(images_dir, coco_data):
    annotated_images = set(img['file_name'] for img in coco_data['images'])
    dataset_images = set(os.listdir(images_dir))

    missing_in_folder = annotated_images - dataset_images
    extra_in_folder = dataset_images - annotated_images

    return missing_in_folder, extra_in_folder

for s in sets:
    coco_data = load_coco_data(annotation_paths[s])
    missing_in_folder, extra_in_folder = verify_dataset(image_dirs[s], coco_data)

    print(f"\n{s.upper()} SET:")
    if not missing_in_folder and not extra_in_folder:
        print("All files and annotations are correctly aligned.")
    else:
        if missing_in_folder:
            print(f"Missing in {s} folder: {len(missing_in_folder)} files")
            for f in list(missing_in_folder)[:5]:
                print(f" - {f}")
        if extra_in_folder:
            print(f"Extra in {s} folder: {len(extra_in_folder)} files")
            for f in list(extra_in_folder)[:5]:
                print(f" - {f}")
# Out:
# TRAIN SET:
# All files and annotations are correctly aligned.
#
# VAL SET:
# All files and annotations are correctly aligned.
#
# TEST SET:
# All files and annotations are correctly aligned.

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
models_dir = "/kaggle/working/models";
if os.path.exists(models_dir):
    shutil.rmtree(models_dir)
if not os.path.exists(models_dir):
    os.mkdir(models_dir)
# !git clone https://github.com/tensorflow/models.git /kaggle/working/models
# Out:
# Cloning into '/kaggle/working/models'...
# remote: Enumerating objects: 96741, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 96741 (delta 7), reused 16 (delta 6), pack-reused 96720
# Receiving objects: 100% (96741/96741), 610.83 MiB | 33.41 MiB/s, done.
# Resolving deltas: 100% (70425/70425), done.

# %%
# %cd /kaggle/working/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# !cp object_detection/packages/tf2/setup.py .
# Out:
# /kaggle/working/models/research

# %%
# !pip install .
# Out:
# Processing /kaggle/working/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object_detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: apache-beam in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (2.46.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (9.5.0)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (5.1.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (3.7.5)
# Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (3.0.8)
# Collecting contextlib2 (from object_detection==0.1)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tf-slim (from object_detection==0.1)
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (1.16.0)
# Collecting pycocotools (from object_detection==0.1)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting lvis (from object_detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl.metadata (856 bytes)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (1.11.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (2.2.1)
# Collecting tf-models-official>=2.5.1 (from object_detection==0.1)
#   Downloading tf_models_official-2.16.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tensorflow_io in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (0.35.0)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from object_detection==0.1) (2.13.1)
# Collecting pyparsing==2.4.7 (from object_detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting sacrebleu<=2.2.0 (from object_detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 2.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object_detection==0.1)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (1.24.3)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object_detection==0.1) (0.4.6)
# Collecting gin-config (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (2.122.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading immutabledict-4.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (1.6.6)
# Requirement already satisfied: oauth2client in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.9.0.80)
# Requirement already satisfied: psutil>=5.4.3 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (5.9.3)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (6.0.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.2.0)
# Collecting seqeval (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow-datasets in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (4.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object_detection==0.1) (0.16.1)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl.metadata (904 bytes)
# Collecting tensorflow-text~=2.16.1 (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading tensorflow_text-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting tensorflow~=2.16.1 (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting tf-keras>=2.16.0 (from tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading tf_keras-2.16.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->object_detection==0.1) (2023.4)
# Requirement already satisfied: absl-py>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from tf-slim->object_detection==0.1) (1.4.0)
# Requirement already satisfied: protobuf<4,>3.12.2 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (3.20.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (1.7)
# Requirement already satisfied: orjson<4.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (3.9.10)
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object_detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (1.9.3)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (1.60.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (0.21.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (0.6.1)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (3.13.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (1.23.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from apache-beam->object_detection==0.1) (0.22.0)
# Collecting pyarrow<10.0.0,>=3.0.0 (from apache-beam->object_detection==0.1)
#   Downloading pyarrow-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: cycler>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from lvis->object_detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from lvis->object_detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /opt/conda/lib/python3.10/site-packages (from lvis->object_detection==0.1) (4.9.0.80)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->object_detection==0.1) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.35.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow_io->object_detection==0.1) (0.35.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (2.26.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (3.0.1)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.10/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object_detection==0.1) (0.6.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (2024.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (4.66.1)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (8.0.4)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (1.26.18)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (6.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object_detection==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object_detection==0.1) (3.6)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (16.0.6)
# Collecting ml-dtypes~=0.3.1 (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (69.0.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (1.14.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras (from object_detection==0.1)
#   Downloading keras-3.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras->object_detection==0.1) (13.7.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras->object_detection==0.1) (0.0.7)
# Collecting optree (from keras->object_detection==0.1)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree~=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object_detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object_detection==0.1) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/conda/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object_detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object_detection==0.1) (4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->object_detection==0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->object_detection==0.1) (2.17.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/conda/lib/python3.10/site-packages (from seqeval->tf-models-official>=2.5.1->object_detection==0.1) (1.2.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (8.1.7)
# Requirement already satisfied: etils>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (1.6.0)
# Requirement already satisfied: promise in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (0.14.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (0.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (0.42.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (2024.3.0)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (6.1.1)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object_detection==0.1) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object_detection==0.1) (4.2.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->object_detection==0.1) (0.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object_detection==0.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object_detection==0.1) (3.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (3.0.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.10/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object_detection==0.1) (1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow~=2.16.1->tf-models-official>=2.5.1->object_detection==0.1) (2.1.3)
# Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.1 MB/s eta 0:00:00
# Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 5.6 MB/s eta 0:00:00
# Downloading tf_models_official-2.16.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 43.5 MB/s eta 0:00:00:00:01
# Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 15.4 MB/s eta 0:00:00
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 18.3 MB/s eta 0:00:00
# Downloading pyarrow-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 39.6 MB/s eta 0:00:00:00:0100:01
# Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.2 MB/s eta 0:00:00:00:0100:01
# Downloading keras-3.2.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.9 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 50.5 MB/s eta 0:00:00:00:01
# Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 12.8 MB/s eta 0:00:00
# Downloading tensorflow_text-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 61.2 MB/s eta 0:00:00:00:0100:01
# Downloading tf_keras-2.16.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.0 MB/s eta 0:00:00:00:01
# Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 2.4 MB/s eta 0:00:00
# Downloading immutabledict-4.2.0-py3-none-any.whl (4.7 kB)
# Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 12.7 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 62.5 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: object_detection, avro-python3, dill, seqeval
#   Building wheel for object_detection (setup.py) ... done
#   Created wheel for object_detection: filename=object_detection-0.1-py3-none-any.whl size=21878671 sha256=8c430e633d61fd2a53a3ff0b4c33eaf3afb333f2b49b744190df910cce4f1835
#   Stored in directory: /tmp/pip-ephem-wheel-cache-roet3w_t/wheels/e6/5c/1f/32444df4025257dccdc9eafab2d06b65752494ee9ca01a388c
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43992 sha256=c65d98c9683fcd3dbd138d3ee35ceef6574aa5fb65eb58f77ff6f86bd2a0d707
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78540 sha256=7f07970c208c7d6e851914ef7f1982aef35db2e933ac631f493768a41de55407
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=7ebefc457b3e4ef344ebfd2c3c7cf732ffb64009b85b0ee4e3f7f1441dacb57d
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built object_detection avro-python3 dill seqeval
# Installing collected packages: gin-config, tf-slim, tensorflow-model-optimization, pyparsing, pyarrow, portalocker, optree, ml-dtypes, immutabledict, dill, contextlib2, avro-python3, tensorboard, sacrebleu, seqeval, keras, tensorflow, pycocotools, lvis, tf-keras, tensorflow-text, tf-models-official, object_detection
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 15.0.2
#     Uninstalling pyarrow-15.0.2:
#       Successfully uninstalled pyarrow-15.0.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
#   Attempting uninstall: tf-keras
#     Found existing installation: tf_keras 2.15.1
#     Uninstalling tf_keras-2.15.1:
#       Successfully uninstalled tf_keras-2.15.1
#   Attempting uninstall: tensorflow-text
#     Found existing installation: tensorflow-text 2.15.0
#     Uninstalling tensorflow-text-2.15.0:
#       Successfully uninstalled tensorflow-text-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.8.2 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.5 which is incompatible.
# multiprocess 0.70.16 requires dill>=0.3.8, but you have dill 0.3.1.1 which is incompatible.
# pathos 0.3.2 requires dill>=0.3.8, but you have dill 0.3.1.1 which is incompatible.
# pytoolconfig 1.3.1 requires packaging>=23.2, but you have packaging 21.3 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow-decision-forests 1.8.1 requires tensorflow~=2.15.0, but you have tensorflow 2.16.1 which is incompatible.
# xarray 2024.2.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# Successfully installed avro-python3-1.10.2 contextlib2-21.6.0 dill-0.3.1.1 gin-config-0.5.0 immutabledict-4.2.0 keras-3.2.0 lvis-0.5.3 ml-dtypes-0.3.2 object_detection-0.1 optree-0.11.0 portalocker-2.8.2 pyarrow-9.0.0 pycocotools-2.0.7 pyparsing-2.4.7 sacrebleu-2.2.0 seqeval-1.2.2 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow-model-optimization-0.8.0 tensorflow-text-2.16.1 tf-keras-2.16.0 tf-models-official-2.16.0 tf-slim-1.1.0

# %%
# %cd /kaggle/working/models/research/
# Out:
# /kaggle/working/models/research

# %%
# !python object_detection/dataset_tools/create_coco_tf_record.py \
    --logtostderr \
    --train_image_dir=/kaggle/working/train \
    --val_image_dir=/kaggle/working/val \
    --test_image_dir=/kaggle/working/test \
    --train_annotations_file=/kaggle/working/train_annotations.coco.json \
    --val_annotations_file=/kaggle/working/val_annotations.coco.json \
    --testdev_annotations_file=/kaggle/working/test_annotations.coco.json \
    --output_dir=/kaggle/working/coco_tf_records \
    --include_masks=False
# Out:
# I0331 17:02:52.380677 136406083946304 create_coco_tf_record.py:399] Found groundtruth annotations. Building annotations index.
# I0331 17:02:52.572237 136406083946304 create_coco_tf_record.py:411] 0 images are missing annotations.
# I0331 17:02:52.572844 136406083946304 create_coco_tf_record.py:441] On image 0 of 13138
# I0331 17:02:52.885965 136406083946304 create_coco_tf_record.py:441] On image 100 of 13138
# I0331 17:02:53.151529 136406083946304 create_coco_tf_record.py:441] On image 200 of 13138
# I0331 17:02:53.398221 136406083946304 create_coco_tf_record.py:441] On image 300 of 13138
# I0331 17:02:53.647791 136406083946304 create_coco_tf_record.py:441] On image 400 of 13138
# I0331 17:02:53.911189 136406083946304 create_coco_tf_record.py:441] On image 500 of 13138
# I0331 17:02:54.198255 136406083946304 create_coco_tf_record.py:441] On image 600 of 13138
# I0331 17:03:20.576917 136406083946304 create_coco_tf_record.py:411] 0 images are missing annotations.
# I0331 17:03:20.577043 136406083946304 create_coco_tf_record.py:441] On image 0 of 1877
# I0331 17:03:20.678613 136406083946304 create_coco_tf_record.py:441] On image 100 of 1877
# I0331 17:03:20.787515 136406083946304 create_coco_tf_record.py:441] On image 200 of 1877
# I0331 17:03:20.875870 136406083946304 create_coco_tf_record.py:441] On image 300 of 1877
# I0331 17:03:20.967481 136406083946304 create_coco_tf_record.py:441] On image 400 of 1877
# I0331 17:03:21.076231 136406083946304 create_coco_tf_record.py:441] On image 500 of 1877
# I0331 17:03:21.188443 136406083946304 create_coco_tf_record.py:441] On image 600 of 1877
# I0331 17:03:21.279114 136406083946304 create_coco_tf_record.py:441] On image 700 of 1877
# I0331 17:03:21.389417 136406083946304 create_coco_tf_record.py:441] On image 800 of 1877
# I0331 17:03:21.477311 136406083946304 create_coco_tf_record.py:441] On image 900 of 1877
# I0331 17:03:21.559956 136406083946304 create_coco_tf_record.py:441] On image 1000 of 1877
# I0331 17:03:21.643232 136406083946304 create_coco_tf_record.py:441] On image 1100 of 1877
# I0331 17:03:21.720198 136406083946304 create_coco_tf_record.py:441] On image 1200 of 1877
# I0331 17:03:21.814078 136406083946304 create_coco_tf_record.py:441] On image 1300 of 1877
# I0331 17:03:21.912734 136406083946304 create_coco_tf_record.py:441] On image 1400 of 1877
# I0331 17:03:22.011840 136406083946304 create_coco_tf_record.py:441] On image 1500 of 1877
# I0331 17:03:22.117859 136406083946304 create_coco_tf_record.py:441] On image 1600 of 1877
# I0331 17:03:22.232008 136406083946304 create_coco_tf_record.py:441] On image 1700 of 1877
# I0331 17:03:22.320280 136406083946304 create_coco_tf_record.py:441] On image 1800 of 1877
# I0331 17:03:22.406119 136406083946304 create_coco_tf_record.py:465] Finished writing, skipped 1 annotations.

# %%
label_map = """item {
  id: 1
  name: 'Varroa'
}"""

with open("/kaggle/working/label_map.pbtxt", "w") as file:
    file.write(label_map)

# %%
efficientdet_src = "/kaggle/input/efficientdet-d0-coco17-tpu-32/efficientdet_d0_coco17_tpu-32"
efficientdet_dest = "/kaggle/working/efficientdet_d0_coco17_tpu-32/";
if os.path.exists(efficientdet_dest):
    shutil.rmtree(efficientdet_dest)
shutil.copytree(efficientdet_src, efficientdet_dest)
# Out:
# '/kaggle/working/efficientdet_d0_coco17_tpu-32/'

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format
import shutil
import os

config_path = '/kaggle/working/models/research/object_detection/configs/tf2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config'
modified_config_path = '/kaggle/working/models/research/object_detection/configs/tf2/modified_effdet_d0.config'

config = config_util.get_configs_from_pipeline_file(config_path)
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(config_path, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

pipeline_config.train_config.batch_size = 4
pipeline_config.model.ssd.num_classes = 1
pipeline_config.train_config.fine_tune_checkpoint = "/kaggle/working/efficientdet_d0_coco17_tpu-32/checkpoint/ckpt-0"
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path = "/kaggle/working/label_map.pbtxt"
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = ["/kaggle/working/coco_tf_records/coco_train.record-?????-of-00100",]
pipeline_config.eval_input_reader[0].label_map_path = "/kaggle/working/label_map.pbtxt"
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = ["/kaggle/working/coco_tf_records/coco_val.record-?????-of-00050",]

config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(modified_config_path, "wb") as f:
    f.write(config_text)

print(f"Config file modified and saved to {modified_config_path}")
# Out:
# Config file modified and saved to /kaggle/working/models/research/object_detection/configs/tf2/modified_effdet_d0.config

# %%
# !pip uninstall tensorflow --y
# !pip install tensorflow==2.13.0

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')

# %%
model_dir = "/kaggle/working/efficientdet_d0_train"
if os.path.exists(model_dir):
    shutil.rmtree(model_dir)

# %%
# !python /kaggle/working/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=/kaggle/working/models/research/object_detection/configs/tf2/modified_effdet_d0.config \
    --model_dir=/kaggle/working/efficientdet_d0_train \
    --alsologtostderr \
    --num_train_steps=10000 \
    --sample_1_of_n_eval_examples=1 \
    --num_eval_steps=100
# Out:
# I0331 19:48:08.803999 138583278085952 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0331 19:48:08.838015 138583278085952 config_util.py:552] Maybe overwriting train_steps: 10000
# I0331 19:48:08.838391 138583278085952 config_util.py:552] Maybe overwriting use_bfloat16: False
# I0331 19:48:08.854880 138583278085952 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0331 19:48:08.855222 138583278085952 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I0331 19:48:08.855417 138583278085952 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I0331 19:48:08.870341 138583278085952 efficientnet_model.py:143] round_filter input=32 output=32
# I0331 19:48:08.937191 138583278085952 efficientnet_model.py:143] round_filter input=32 output=32
# I0331 19:48:08.937538 138583278085952 efficientnet_model.py:143] round_filter input=16 output=16
# I0331 19:48:09.093681 138583278085952 efficientnet_model.py:143] round_filter input=16 output=16
# I0331 19:48:09.094026 138583278085952 efficientnet_model.py:143] round_filter input=24 output=24
# I0331 19:48:09.523559 138583278085952 efficientnet_model.py:143] round_filter input=24 output=24
# I0331 19:48:09.523931 138583278085952 efficientnet_model.py:143] round_filter input=40 output=40
# I0331 19:48:09.971688 138583278085952 efficientnet_model.py:143] round_filter input=40 output=40
# I0331 19:48:09.972079 138583278085952 efficientnet_model.py:143] round_filter input=80 output=80
# I0331 19:48:10.610258 138583278085952 efficientnet_model.py:143] round_filter input=80 output=80
# I0331 19:48:10.610604 138583278085952 efficientnet_model.py:143] round_filter input=112 output=112
# I0331 19:48:11.253660 138583278085952 efficientnet_model.py:143] round_filter input=112 output=112
# I0331 19:48:11.254033 138583278085952 efficientnet_model.py:143] round_filter input=192 output=192
# I0331 19:48:12.117932 138583278085952 efficientnet_model.py:143] round_filter input=192 output=192
# I0331 19:48:12.118315 138583278085952 efficientnet_model.py:143] round_filter input=320 output=320
# I0331 19:48:12.326423 138583278085952 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0331 19:48:12.445202 138583278085952 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# W0331 19:48:12.547372 138583278085952 deprecation.py:364] From /opt/conda/lib/python3.10/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# I0331 19:48:12.559850 138583278085952 dataset_builder.py:162] Reading unweighted datasets: ['/kaggle/working/coco_tf_records/coco_train.record-?????-of-00100']
# I0331 19:48:12.562978 138583278085952 dataset_builder.py:79] Reading record datasets for input file: ['/kaggle/working/coco_tf_records/coco_train.record-?????-of-00100']
# I0331 19:48:12.563377 138583278085952 dataset_builder.py:80] Number of filenames to read: 100
# W0331 19:48:12.576605 138583278085952 deprecation.py:364] From /opt/conda/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0331 19:48:12.614616 138583278085952 deprecation.py:364] From /opt/conda/lib/python3.10/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0331 19:48:25.485486 138583278085952 deprecation.py:364] From /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0331 19:48:32.687963 138583278085952 deprecation.py:364] From /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /opt/conda/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0331 19:48:55.094815 138580097738496 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0331 19:49:12.466417 138580097738496 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# W0331 19:49:29.882395 138580131309312 deprecation.py:569] From /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0331 19:49:33.048353 138580131309312 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# W0331 19:49:41.264932 138580131309312 utils.py:82] Gradients do not exist for variables ['top_conv2d/kernel:0', 'top_bn/gamma:0', 'top_bn/beta:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0331 19:49:48.422818 138580131309312 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# W0331 19:49:56.260157 138580131309312 utils.py:82] Gradients do not exist for variables ['top_conv2d/kernel:0', 'top_bn/gamma:0', 'top_bn/beta:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0331 19:50:01.346335 138580131309312 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# W0331 19:50:10.274772 138580131309312 utils.py:82] Gradients do not exist for variables ['top_conv2d/kernel:0', 'top_bn/gamma:0', 'top_bn/beta:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0331 19:50:16.268007 138580131309312 api.py:460] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# W0331 19:50:24.137307 138580131309312 utils.py:82] Gradients do not exist for variables ['top_conv2d/kernel:0', 'top_bn/gamma:0', 'top_bn/beta:0', 'logits/kernel:0', 'logits/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0331 19:57:18.821574 138583278085952 model_lib_v2.py:705] Step 100 per-step time 4.697s
# I0331 19:57:18.822395 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 1.0317913,
#  'Loss/localization_loss': 0.73125607,
#  'Loss/regularization_loss': 0.009842271,
#  'Loss/total_loss': 1.7728896,
#  'learning_rate': 0.00416}
# I0331 20:03:37.610295 138583278085952 model_lib_v2.py:705] Step 200 per-step time 3.788s
# I0331 20:03:37.611048 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.90331376,
#  'Loss/localization_loss': 0.5912908,
#  'Loss/regularization_loss': 0.0098940795,
#  'Loss/total_loss': 1.5044986,
#  'learning_rate': 0.0073200003}
# I0331 20:09:37.526532 138583278085952 model_lib_v2.py:705] Step 300 per-step time 3.599s
# I0331 20:09:37.527214 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.9962423,
#  'Loss/localization_loss': 0.5602541,
#  'Loss/regularization_loss': 0.010266861,
#  'Loss/total_loss': 1.5667632,
#  'learning_rate': 0.010480001}
# I0331 20:15:52.560665 138583278085952 model_lib_v2.py:705] Step 400 per-step time 3.750s
# I0331 20:15:52.561751 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.9031531,
#  'Loss/localization_loss': 0.6438888,
#  'Loss/regularization_loss': 0.010295213,
#  'Loss/total_loss': 1.557337,
#  'learning_rate': 0.0136400005}
# I0331 20:21:48.845547 138583278085952 model_lib_v2.py:705] Step 500 per-step time 3.563s
# I0331 20:21:48.846302 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7989312,
#  'Loss/localization_loss': 0.507406,
#  'Loss/regularization_loss': 0.010339382,
#  'Loss/total_loss': 1.3166766,
#  'learning_rate': 0.016800001}
# I0331 20:27:44.985575 138583278085952 model_lib_v2.py:705] Step 600 per-step time 3.561s
# I0331 20:27:44.986315 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.85672104,
#  'Loss/localization_loss': 0.49863178,
#  'Loss/regularization_loss': 0.010394984,
#  'Loss/total_loss': 1.3657478,
#  'learning_rate': 0.019960001}
# I0331 20:33:44.639512 138583278085952 model_lib_v2.py:705] Step 700 per-step time 3.597s
# I0331 20:33:44.640880 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.75023067,
#  'Loss/localization_loss': 0.5049038,
#  'Loss/regularization_loss': 0.010448516,
#  'Loss/total_loss': 1.265583,
#  'learning_rate': 0.023120001}
# I0331 20:39:43.996016 138583278085952 model_lib_v2.py:705] Step 800 per-step time 3.594s
# I0331 20:39:43.996805 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7039165,
#  'Loss/localization_loss': 0.49152526,
#  'Loss/regularization_loss': 0.010516978,
#  'Loss/total_loss': 1.2059587,
#  'learning_rate': 0.02628}
# I0331 20:45:38.745512 138583278085952 model_lib_v2.py:705] Step 900 per-step time 3.548s
# I0331 20:45:38.746299 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 1.0013217,
#  'Loss/localization_loss': 0.6674486,
#  'Loss/regularization_loss': 0.010579642,
#  'Loss/total_loss': 1.6793499,
#  'learning_rate': 0.02944}
# I0331 20:51:37.288544 138583278085952 model_lib_v2.py:705] Step 1000 per-step time 3.585s
# I0331 20:51:37.289533 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.78574246,
#  'Loss/localization_loss': 0.40787536,
#  'Loss/regularization_loss': 0.010661381,
#  'Loss/total_loss': 1.2042792,
#  'learning_rate': 0.0326}
# I0331 20:57:34.550487 138583278085952 model_lib_v2.py:705] Step 1100 per-step time 3.573s
# I0331 20:57:34.551342 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6321674,
#  'Loss/localization_loss': 0.39844072,
#  'Loss/regularization_loss': 0.010773554,
#  'Loss/total_loss': 1.0413816,
#  'learning_rate': 0.03576}
# I0331 21:03:29.482892 138583278085952 model_lib_v2.py:705] Step 1200 per-step time 3.549s
# I0331 21:03:29.483880 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6598654,
#  'Loss/localization_loss': 0.3464123,
#  'Loss/regularization_loss': 0.010881744,
#  'Loss/total_loss': 1.0171595,
#  'learning_rate': 0.03892}
# I0331 21:09:22.951806 138583278085952 model_lib_v2.py:705] Step 1300 per-step time 3.535s
# I0331 21:09:22.952598 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.88343847,
#  'Loss/localization_loss': 0.7700117,
#  'Loss/regularization_loss': 0.0109708235,
#  'Loss/total_loss': 1.6644211,
#  'learning_rate': 0.04208}
# I0331 21:15:16.274778 138583278085952 model_lib_v2.py:705] Step 1400 per-step time 3.533s
# I0331 21:15:16.275865 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.8311261,
#  'Loss/localization_loss': 0.5697012,
#  'Loss/regularization_loss': 0.011092389,
#  'Loss/total_loss': 1.4119196,
#  'learning_rate': 0.04524}
# I0331 21:21:09.993281 138583278085952 model_lib_v2.py:705] Step 1500 per-step time 3.537s
# I0331 21:21:09.994334 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.71778584,
#  'Loss/localization_loss': 0.46962208,
#  'Loss/regularization_loss': 0.011290433,
#  'Loss/total_loss': 1.1986983,
#  'learning_rate': 0.0484}
# I0331 21:27:06.099096 138583278085952 model_lib_v2.py:705] Step 1600 per-step time 3.561s
# I0331 21:27:06.099872 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.78250706,
#  'Loss/localization_loss': 0.5900679,
#  'Loss/regularization_loss': 0.011413949,
#  'Loss/total_loss': 1.3839889,
#  'learning_rate': 0.05156}
# I0331 21:32:58.804679 138583278085952 model_lib_v2.py:705] Step 1700 per-step time 3.527s
# I0331 21:32:58.805479 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.95625967,
#  'Loss/localization_loss': 0.53291464,
#  'Loss/regularization_loss': 0.011556372,
#  'Loss/total_loss': 1.5007308,
#  'learning_rate': 0.05472}
# I0331 21:38:52.082907 138583278085952 model_lib_v2.py:705] Step 1800 per-step time 3.533s
# I0331 21:38:52.083710 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6375506,
#  'Loss/localization_loss': 0.38346547,
#  'Loss/regularization_loss': 0.011697218,
#  'Loss/total_loss': 1.0327133,
#  'learning_rate': 0.05788}
# I0331 21:44:43.795752 138583278085952 model_lib_v2.py:705] Step 1900 per-step time 3.517s
# I0331 21:44:43.796507 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6328355,
#  'Loss/localization_loss': 0.46468988,
#  'Loss/regularization_loss': 0.011854538,
#  'Loss/total_loss': 1.1093799,
#  'learning_rate': 0.06104}
# I0331 21:50:35.911559 138583278085952 model_lib_v2.py:705] Step 2000 per-step time 3.521s
# I0331 21:50:35.912269 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5982501,
#  'Loss/localization_loss': 0.3519456,
#  'Loss/regularization_loss': 0.012083891,
#  'Loss/total_loss': 0.96227956,
#  'learning_rate': 0.06420001}
# I0331 21:56:31.548159 138583278085952 model_lib_v2.py:705] Step 2100 per-step time 3.556s
# I0331 21:56:31.548980 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7978626,
#  'Loss/localization_loss': 0.49917182,
#  'Loss/regularization_loss': 0.012234358,
#  'Loss/total_loss': 1.3092687,
#  'learning_rate': 0.067360006}
# I0331 22:02:24.168812 138583278085952 model_lib_v2.py:705] Step 2200 per-step time 3.526s
# I0331 22:02:24.170210 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.8037746,
#  'Loss/localization_loss': 0.4893335,
#  'Loss/regularization_loss': 0.012409503,
#  'Loss/total_loss': 1.3055177,
#  'learning_rate': 0.070520006}
# I0331 22:08:13.433939 138583278085952 model_lib_v2.py:705] Step 2300 per-step time 3.493s
# I0331 22:08:13.434700 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7870824,
#  'Loss/localization_loss': 0.49907485,
#  'Loss/regularization_loss': 0.012631034,
#  'Loss/total_loss': 1.2987883,
#  'learning_rate': 0.073680006}
# I0331 22:14:03.889819 138583278085952 model_lib_v2.py:705] Step 2400 per-step time 3.505s
# I0331 22:14:03.890506 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6617566,
#  'Loss/localization_loss': 0.25506806,
#  'Loss/regularization_loss': 0.012852962,
#  'Loss/total_loss': 0.9296776,
#  'learning_rate': 0.076840006}
# I0331 22:19:50.322274 138583278085952 model_lib_v2.py:705] Step 2500 per-step time 3.464s
# I0331 22:19:50.322976 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.74670106,
#  'Loss/localization_loss': 0.53295094,
#  'Loss/regularization_loss': 0.013206389,
#  'Loss/total_loss': 1.2928584,
#  'learning_rate': 0.08}
# I0331 22:25:36.303933 138583278085952 model_lib_v2.py:705] Step 2600 per-step time 3.460s
# I0331 22:25:36.304787 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7258138,
#  'Loss/localization_loss': 0.6556984,
#  'Loss/regularization_loss': 0.013511972,
#  'Loss/total_loss': 1.3950242,
#  'learning_rate': 0.079999976}
# I0331 22:31:20.430709 138583278085952 model_lib_v2.py:705] Step 2700 per-step time 3.441s
# I0331 22:31:20.431473 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5132627,
#  'Loss/localization_loss': 0.35312325,
#  'Loss/regularization_loss': 0.013810912,
#  'Loss/total_loss': 0.88019687,
#  'learning_rate': 0.07999991}
# I0331 22:37:03.036754 138583278085952 model_lib_v2.py:705] Step 2800 per-step time 3.426s
# I0331 22:37:03.037760 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.63800216,
#  'Loss/localization_loss': 0.44450736,
#  'Loss/regularization_loss': 0.01441247,
#  'Loss/total_loss': 1.0969219,
#  'learning_rate': 0.0799998}
# I0331 22:42:49.188859 138583278085952 model_lib_v2.py:705] Step 2900 per-step time 3.462s
# I0331 22:42:49.189619 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6225112,
#  'Loss/localization_loss': 0.6428897,
#  'Loss/regularization_loss': 0.014638712,
#  'Loss/total_loss': 1.2800395,
#  'learning_rate': 0.07999964}
# I0331 22:48:40.508535 138583278085952 model_lib_v2.py:705] Step 3000 per-step time 3.513s
# I0331 22:48:40.509220 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3906079,
#  'Loss/localization_loss': 0.17442161,
#  'Loss/regularization_loss': 0.014870304,
#  'Loss/total_loss': 0.5798998,
#  'learning_rate': 0.07999944}
# I0331 22:54:34.761185 138583278085952 model_lib_v2.py:705] Step 3100 per-step time 3.543s
# I0331 22:54:34.762062 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.88668615,
#  'Loss/localization_loss': 0.3756474,
#  'Loss/regularization_loss': 0.015287733,
#  'Loss/total_loss': 1.2776213,
#  'learning_rate': 0.07999919}
# I0331 23:00:29.205989 138583278085952 model_lib_v2.py:705] Step 3200 per-step time 3.544s
# I0331 23:00:29.206965 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.85872775,
#  'Loss/localization_loss': 0.5094022,
#  'Loss/regularization_loss': 0.015737355,
#  'Loss/total_loss': 1.3838673,
#  'learning_rate': 0.0799989}
# I0331 23:06:20.069783 138583278085952 model_lib_v2.py:705] Step 3300 per-step time 3.509s
# I0331 23:06:20.070535 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7256809,
#  'Loss/localization_loss': 0.4534265,
#  'Loss/regularization_loss': 0.015934488,
#  'Loss/total_loss': 1.1950419,
#  'learning_rate': 0.07999857}
# I0331 23:12:13.046754 138583278085952 model_lib_v2.py:705] Step 3400 per-step time 3.530s
# I0331 23:12:13.047502 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7674118,
#  'Loss/localization_loss': 0.44375297,
#  'Loss/regularization_loss': 0.016157955,
#  'Loss/total_loss': 1.2273228,
#  'learning_rate': 0.07999819}
# I0331 23:18:05.157932 138583278085952 model_lib_v2.py:705] Step 3500 per-step time 3.521s
# I0331 23:18:05.158628 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6716086,
#  'Loss/localization_loss': 0.61973566,
#  'Loss/regularization_loss': 0.016359631,
#  'Loss/total_loss': 1.307704,
#  'learning_rate': 0.07999776}
# I0331 23:23:56.249153 138583278085952 model_lib_v2.py:705] Step 3600 per-step time 3.511s
# I0331 23:23:56.249898 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.35563928,
#  'Loss/localization_loss': 0.27509207,
#  'Loss/regularization_loss': 0.016607761,
#  'Loss/total_loss': 0.6473391,
#  'learning_rate': 0.0799973}
# I0331 23:30:00.475199 138583278085952 model_lib_v2.py:705] Step 3700 per-step time 3.642s
# I0331 23:30:00.476328 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.626959,
#  'Loss/localization_loss': 0.49396598,
#  'Loss/regularization_loss': 0.016831608,
#  'Loss/total_loss': 1.1377566,
#  'learning_rate': 0.07999679}
# I0331 23:35:55.569031 138583278085952 model_lib_v2.py:705] Step 3800 per-step time 3.551s
# I0331 23:35:55.570681 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.49422467,
#  'Loss/localization_loss': 0.44383988,
#  'Loss/regularization_loss': 0.017053446,
#  'Loss/total_loss': 0.95511794,
#  'learning_rate': 0.07999623}
# I0331 23:41:47.836357 138583278085952 model_lib_v2.py:705] Step 3900 per-step time 3.523s
# I0331 23:41:47.837470 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.60289025,
#  'Loss/localization_loss': 0.40437078,
#  'Loss/regularization_loss': 0.017249696,
#  'Loss/total_loss': 1.0245107,
#  'learning_rate': 0.07999563}
# I0331 23:47:39.194362 138583278085952 model_lib_v2.py:705] Step 4000 per-step time 3.514s
# I0331 23:47:39.195202 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.41526243,
#  'Loss/localization_loss': 0.2150516,
#  'Loss/regularization_loss': 0.017477999,
#  'Loss/total_loss': 0.64779204,
#  'learning_rate': 0.079994984}
# I0331 23:53:26.615734 138583278085952 model_lib_v2.py:705] Step 4100 per-step time 3.474s
# I0331 23:53:26.616581 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5016128,
#  'Loss/localization_loss': 0.38930267,
#  'Loss/regularization_loss': 0.017674293,
#  'Loss/total_loss': 0.9085897,
#  'learning_rate': 0.07999428}
# I0331 23:59:07.652249 138583278085952 model_lib_v2.py:705] Step 4200 per-step time 3.410s
# I0331 23:59:07.653446 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5760306,
#  'Loss/localization_loss': 0.2742946,
#  'Loss/regularization_loss': 0.017831987,
#  'Loss/total_loss': 0.8681572,
#  'learning_rate': 0.07999355}
# I0401 00:04:51.896997 138583278085952 model_lib_v2.py:705] Step 4300 per-step time 3.442s
# I0401 00:04:51.897805 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7209489,
#  'Loss/localization_loss': 0.5025325,
#  'Loss/regularization_loss': 0.018077215,
#  'Loss/total_loss': 1.2415586,
#  'learning_rate': 0.07999277}
# I0401 00:10:36.250906 138583278085952 model_lib_v2.py:705] Step 4400 per-step time 3.443s
# I0401 00:10:36.252110 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.52797544,
#  'Loss/localization_loss': 0.64646506,
#  'Loss/regularization_loss': 0.018277016,
#  'Loss/total_loss': 1.1927176,
#  'learning_rate': 0.07999195}
# I0401 00:16:21.711242 138583278085952 model_lib_v2.py:705] Step 4500 per-step time 3.455s
# I0401 00:16:21.712011 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.7505367,
#  'Loss/localization_loss': 0.46952695,
#  'Loss/regularization_loss': 0.018460006,
#  'Loss/total_loss': 1.2385237,
#  'learning_rate': 0.07999108}
# I0401 00:22:08.081131 138583278085952 model_lib_v2.py:705] Step 4600 per-step time 3.464s
# I0401 00:22:08.081927 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.62487954,
#  'Loss/localization_loss': 0.22990374,
#  'Loss/regularization_loss': 0.018685099,
#  'Loss/total_loss': 0.8734684,
#  'learning_rate': 0.07999016}
# I0401 00:27:50.166364 138583278085952 model_lib_v2.py:705] Step 4700 per-step time 3.421s
# I0401 00:27:50.167104 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.47352096,
#  'Loss/localization_loss': 0.34723088,
#  'Loss/regularization_loss': 0.018844804,
#  'Loss/total_loss': 0.8395966,
#  'learning_rate': 0.0799892}
# I0401 00:33:35.056872 138583278085952 model_lib_v2.py:705] Step 4800 per-step time 3.449s
# I0401 00:33:35.057892 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.52756923,
#  'Loss/localization_loss': 0.16973762,
#  'Loss/regularization_loss': 0.018980429,
#  'Loss/total_loss': 0.71628726,
#  'learning_rate': 0.079988204}
# I0401 00:39:17.054539 138583278085952 model_lib_v2.py:705] Step 4900 per-step time 3.420s
# I0401 00:39:17.055376 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.4846218,
#  'Loss/localization_loss': 0.279934,
#  'Loss/regularization_loss': 0.019167589,
#  'Loss/total_loss': 0.78372335,
#  'learning_rate': 0.07998715}
# I0401 00:44:58.693881 138583278085952 model_lib_v2.py:705] Step 5000 per-step time 3.416s
# I0401 00:44:58.694550 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3539674,
#  'Loss/localization_loss': 0.29007828,
#  'Loss/regularization_loss': 0.019455329,
#  'Loss/total_loss': 0.663501,
#  'learning_rate': 0.07998606}
# I0401 00:50:44.324952 138583278085952 model_lib_v2.py:705] Step 5100 per-step time 3.456s
# I0401 00:50:44.326014 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.53706306,
#  'Loss/localization_loss': 0.41717505,
#  'Loss/regularization_loss': 0.019591045,
#  'Loss/total_loss': 0.97382915,
#  'learning_rate': 0.07998492}
# I0401 00:56:26.896590 138583278085952 model_lib_v2.py:705] Step 5200 per-step time 3.426s
# I0401 00:56:26.897300 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3980434,
#  'Loss/localization_loss': 0.30168405,
#  'Loss/regularization_loss': 0.019766867,
#  'Loss/total_loss': 0.71949434,
#  'learning_rate': 0.07998374}
# I0401 01:02:09.241071 138583278085952 model_lib_v2.py:705] Step 5300 per-step time 3.423s
# I0401 01:02:09.241830 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5205189,
#  'Loss/localization_loss': 0.16688263,
#  'Loss/regularization_loss': 0.019945968,
#  'Loss/total_loss': 0.7073475,
#  'learning_rate': 0.07998252}
# I0401 01:07:54.176285 138583278085952 model_lib_v2.py:705] Step 5400 per-step time 3.449s
# I0401 01:07:54.177012 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6610803,
#  'Loss/localization_loss': 0.57468694,
#  'Loss/regularization_loss': 0.020152679,
#  'Loss/total_loss': 1.2559199,
#  'learning_rate': 0.079981245}
# I0401 01:13:38.055272 138583278085952 model_lib_v2.py:705] Step 5500 per-step time 3.439s
# I0401 01:13:38.056508 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.52551556,
#  'Loss/localization_loss': 0.3821514,
#  'Loss/regularization_loss': 0.020424912,
#  'Loss/total_loss': 0.9280919,
#  'learning_rate': 0.07997993}
# I0401 01:19:22.670825 138583278085952 model_lib_v2.py:705] Step 5600 per-step time 3.446s
# I0401 01:19:22.672038 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.46755242,
#  'Loss/localization_loss': 0.37490296,
#  'Loss/regularization_loss': 0.020591743,
#  'Loss/total_loss': 0.8630471,
#  'learning_rate': 0.07997857}
# I0401 01:25:03.652608 138583278085952 model_lib_v2.py:705] Step 5700 per-step time 3.410s
# I0401 01:25:03.653418 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.92674625,
#  'Loss/localization_loss': 0.666065,
#  'Loss/regularization_loss': 0.020796381,
#  'Loss/total_loss': 1.6136076,
#  'learning_rate': 0.07997716}
# I0401 01:30:46.388531 138583278085952 model_lib_v2.py:705] Step 5800 per-step time 3.427s
# I0401 01:30:46.389284 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.60133314,
#  'Loss/localization_loss': 0.51095957,
#  'Loss/regularization_loss': 0.021042816,
#  'Loss/total_loss': 1.1333356,
#  'learning_rate': 0.07997571}
# I0401 01:36:34.958610 138583278085952 model_lib_v2.py:705] Step 5900 per-step time 3.486s
# I0401 01:36:34.959436 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.59003407,
#  'Loss/localization_loss': 0.39636293,
#  'Loss/regularization_loss': 0.021272417,
#  'Loss/total_loss': 1.0076694,
#  'learning_rate': 0.07997422}
# I0401 01:42:18.261484 138583278085952 model_lib_v2.py:705] Step 6000 per-step time 3.433s
# I0401 01:42:18.262683 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3325288,
#  'Loss/localization_loss': 0.17465858,
#  'Loss/regularization_loss': 0.021448249,
#  'Loss/total_loss': 0.5286356,
#  'learning_rate': 0.07997268}
# I0401 01:48:01.700975 138583278085952 model_lib_v2.py:705] Step 6100 per-step time 3.434s
# I0401 01:48:01.701830 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6664507,
#  'Loss/localization_loss': 0.5027405,
#  'Loss/regularization_loss': 0.021581516,
#  'Loss/total_loss': 1.1907728,
#  'learning_rate': 0.0799711}
# I0401 01:53:47.571969 138583278085952 model_lib_v2.py:705] Step 6200 per-step time 3.459s
# I0401 01:53:47.572749 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.41126642,
#  'Loss/localization_loss': 0.3073262,
#  'Loss/regularization_loss': 0.021743493,
#  'Loss/total_loss': 0.7403361,
#  'learning_rate': 0.07996947}
# I0401 01:59:30.687425 138583278085952 model_lib_v2.py:705] Step 6300 per-step time 3.431s
# I0401 01:59:30.688421 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6478147,
#  'Loss/localization_loss': 0.41723737,
#  'Loss/regularization_loss': 0.021866094,
#  'Loss/total_loss': 1.0869181,
#  'learning_rate': 0.0799678}
# I0401 02:05:14.936012 138583278085952 model_lib_v2.py:705] Step 6400 per-step time 3.442s
# I0401 02:05:14.936842 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.67782074,
#  'Loss/localization_loss': 0.4036156,
#  'Loss/regularization_loss': 0.022054143,
#  'Loss/total_loss': 1.1034905,
#  'learning_rate': 0.07996608}
# I0401 02:10:58.801544 138583278085952 model_lib_v2.py:705] Step 6500 per-step time 3.439s
# I0401 02:10:58.802368 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.36947316,
#  'Loss/localization_loss': 0.23090589,
#  'Loss/regularization_loss': 0.022221016,
#  'Loss/total_loss': 0.6226001,
#  'learning_rate': 0.079964325}
# I0401 02:16:43.405890 138583278085952 model_lib_v2.py:705] Step 6600 per-step time 3.446s
# I0401 02:16:43.406951 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6079555,
#  'Loss/localization_loss': 0.46145895,
#  'Loss/regularization_loss': 0.022399513,
#  'Loss/total_loss': 1.091814,
#  'learning_rate': 0.079962514}
# I0401 02:22:27.961624 138583278085952 model_lib_v2.py:705] Step 6700 per-step time 3.446s
# I0401 02:22:27.962569 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5877045,
#  'Loss/localization_loss': 0.46444765,
#  'Loss/regularization_loss': 0.022531362,
#  'Loss/total_loss': 1.0746834,
#  'learning_rate': 0.07996067}
# I0401 02:28:11.014492 138583278085952 model_lib_v2.py:705] Step 6800 per-step time 3.431s
# I0401 02:28:11.015522 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5442131,
#  'Loss/localization_loss': 0.4115053,
#  'Loss/regularization_loss': 0.02261209,
#  'Loss/total_loss': 0.9783305,
#  'learning_rate': 0.079958774}
# I0401 02:33:55.154599 138583278085952 model_lib_v2.py:705] Step 6900 per-step time 3.441s
# I0401 02:33:55.155332 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5135344,
#  'Loss/localization_loss': 0.5064889,
#  'Loss/regularization_loss': 0.02276684,
#  'Loss/total_loss': 1.0427902,
#  'learning_rate': 0.07995682}
# I0401 02:39:41.620494 138583278085952 model_lib_v2.py:705] Step 7000 per-step time 3.465s
# I0401 02:39:41.621230 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5476375,
#  'Loss/localization_loss': 0.51956785,
#  'Loss/regularization_loss': 0.022988379,
#  'Loss/total_loss': 1.0901937,
#  'learning_rate': 0.07995484}
# I0401 02:45:33.849783 138583278085952 model_lib_v2.py:705] Step 7100 per-step time 3.522s
# I0401 02:45:33.850503 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.809374,
#  'Loss/localization_loss': 0.4060303,
#  'Loss/regularization_loss': 0.02312858,
#  'Loss/total_loss': 1.2385328,
#  'learning_rate': 0.07995281}
# I0401 02:51:20.730693 138583278085952 model_lib_v2.py:705] Step 7200 per-step time 3.469s
# I0401 02:51:20.731787 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.62089145,
#  'Loss/localization_loss': 0.37035465,
#  'Loss/regularization_loss': 0.023248091,
#  'Loss/total_loss': 1.0144942,
#  'learning_rate': 0.07995074}
# I0401 02:57:07.110713 138583278085952 model_lib_v2.py:705] Step 7300 per-step time 3.464s
# I0401 02:57:07.111519 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.43977404,
#  'Loss/localization_loss': 0.3100145,
#  'Loss/regularization_loss': 0.02335004,
#  'Loss/total_loss': 0.7731385,
#  'learning_rate': 0.07994863}
# I0401 03:02:58.479499 138583278085952 model_lib_v2.py:705] Step 7400 per-step time 3.514s
# I0401 03:02:58.480476 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5436851,
#  'Loss/localization_loss': 0.28979886,
#  'Loss/regularization_loss': 0.023520341,
#  'Loss/total_loss': 0.8570043,
#  'learning_rate': 0.07994646}
# I0401 03:08:44.177761 138583278085952 model_lib_v2.py:705] Step 7500 per-step time 3.457s
# I0401 03:08:44.178555 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3478371,
#  'Loss/localization_loss': 0.2054506,
#  'Loss/regularization_loss': 0.023685042,
#  'Loss/total_loss': 0.5769727,
#  'learning_rate': 0.07994425}
# I0401 03:14:30.487547 138583278085952 model_lib_v2.py:705] Step 7600 per-step time 3.463s
# I0401 03:14:30.488357 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.53650385,
#  'Loss/localization_loss': 0.3691809,
#  'Loss/regularization_loss': 0.023832807,
#  'Loss/total_loss': 0.9295175,
#  'learning_rate': 0.079942}
# I0401 03:20:17.557301 138583278085952 model_lib_v2.py:705] Step 7700 per-step time 3.471s
# I0401 03:20:17.558030 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6670991,
#  'Loss/localization_loss': 0.5612239,
#  'Loss/regularization_loss': 0.02391728,
#  'Loss/total_loss': 1.2522403,
#  'learning_rate': 0.07993971}
# I0401 03:26:04.985987 138583278085952 model_lib_v2.py:705] Step 7800 per-step time 3.474s
# I0401 03:26:04.987055 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6246662,
#  'Loss/localization_loss': 0.42710698,
#  'Loss/regularization_loss': 0.024091663,
#  'Loss/total_loss': 1.0758648,
#  'learning_rate': 0.07993737}
# I0401 03:31:51.644006 138583278085952 model_lib_v2.py:705] Step 7900 per-step time 3.467s
# I0401 03:31:51.644761 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.48196185,
#  'Loss/localization_loss': 0.34175175,
#  'Loss/regularization_loss': 0.024194468,
#  'Loss/total_loss': 0.8479081,
#  'learning_rate': 0.079934984}
# I0401 03:37:37.758724 138583278085952 model_lib_v2.py:705] Step 8000 per-step time 3.461s
# I0401 03:37:37.759686 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.52959764,
#  'Loss/localization_loss': 0.3574942,
#  'Loss/regularization_loss': 0.024406318,
#  'Loss/total_loss': 0.9114982,
#  'learning_rate': 0.079932556}
# I0401 03:43:28.787081 138583278085952 model_lib_v2.py:705] Step 8100 per-step time 3.510s
# I0401 03:43:28.788182 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.41775277,
#  'Loss/localization_loss': 0.3873516,
#  'Loss/regularization_loss': 0.024503328,
#  'Loss/total_loss': 0.8296077,
#  'learning_rate': 0.079930075}
# I0401 03:49:15.669559 138583278085952 model_lib_v2.py:705] Step 8200 per-step time 3.469s
# I0401 03:49:15.670661 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5021112,
#  'Loss/localization_loss': 0.32864127,
#  'Loss/regularization_loss': 0.024582809,
#  'Loss/total_loss': 0.85533524,
#  'learning_rate': 0.079927556}
# I0401 03:55:02.597052 138583278085952 model_lib_v2.py:705] Step 8300 per-step time 3.469s
# I0401 03:55:02.597909 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.42830813,
#  'Loss/localization_loss': 0.3229759,
#  'Loss/regularization_loss': 0.024705542,
#  'Loss/total_loss': 0.77598953,
#  'learning_rate': 0.07992499}
# I0401 04:00:53.737533 138583278085952 model_lib_v2.py:705] Step 8400 per-step time 3.511s
# I0401 04:00:53.738300 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5746976,
#  'Loss/localization_loss': 0.3493266,
#  'Loss/regularization_loss': 0.024824627,
#  'Loss/total_loss': 0.94884884,
#  'learning_rate': 0.079922386}
# I0401 04:06:40.206484 138583278085952 model_lib_v2.py:705] Step 8500 per-step time 3.465s
# I0401 04:06:40.207261 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.57209456,
#  'Loss/localization_loss': 0.44488588,
#  'Loss/regularization_loss': 0.024955396,
#  'Loss/total_loss': 1.0419358,
#  'learning_rate': 0.07991974}
# I0401 04:12:26.917165 138583278085952 model_lib_v2.py:705] Step 8600 per-step time 3.467s
# I0401 04:12:26.917825 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5988273,
#  'Loss/localization_loss': 0.4291542,
#  'Loss/regularization_loss': 0.025111789,
#  'Loss/total_loss': 1.0530933,
#  'learning_rate': 0.079917036}
# I0401 04:18:13.001391 138583278085952 model_lib_v2.py:705] Step 8700 per-step time 3.461s
# I0401 04:18:13.002086 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6010526,
#  'Loss/localization_loss': 0.2540164,
#  'Loss/regularization_loss': 0.0252665,
#  'Loss/total_loss': 0.8803355,
#  'learning_rate': 0.0799143}
# I0401 04:24:05.638565 138583278085952 model_lib_v2.py:705] Step 8800 per-step time 3.526s
# I0401 04:24:05.639295 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.44664773,
#  'Loss/localization_loss': 0.39621997,
#  'Loss/regularization_loss': 0.025364786,
#  'Loss/total_loss': 0.8682325,
#  'learning_rate': 0.079911515}
# I0401 04:29:54.034575 138583278085952 model_lib_v2.py:705] Step 8900 per-step time 3.484s
# I0401 04:29:54.035412 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.3105106,
#  'Loss/localization_loss': 0.20620842,
#  'Loss/regularization_loss': 0.025521303,
#  'Loss/total_loss': 0.5422403,
#  'learning_rate': 0.079908684}
# I0401 04:35:40.626132 138583278085952 model_lib_v2.py:705] Step 9000 per-step time 3.466s
# I0401 04:35:40.626940 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.9079179,
#  'Loss/localization_loss': 0.57552636,
#  'Loss/regularization_loss': 0.025638701,
#  'Loss/total_loss': 1.509083,
#  'learning_rate': 0.0799058}
# I0401 04:41:34.293736 138583278085952 model_lib_v2.py:705] Step 9100 per-step time 3.537s
# I0401 04:41:34.294690 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6141902,
#  'Loss/localization_loss': 0.35331208,
#  'Loss/regularization_loss': 0.026514351,
#  'Loss/total_loss': 0.99401665,
#  'learning_rate': 0.07990289}
# I0401 04:47:20.163112 138583278085952 model_lib_v2.py:705] Step 9200 per-step time 3.459s
# I0401 04:47:20.163902 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.46588618,
#  'Loss/localization_loss': 0.31693244,
#  'Loss/regularization_loss': 0.026604459,
#  'Loss/total_loss': 0.8094231,
#  'learning_rate': 0.07989992}
# I0401 04:53:05.888151 138583278085952 model_lib_v2.py:705] Step 9300 per-step time 3.457s
# I0401 04:53:05.888889 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.71512145,
#  'Loss/localization_loss': 0.4492488,
#  'Loss/regularization_loss': 0.026674634,
#  'Loss/total_loss': 1.1910448,
#  'learning_rate': 0.07989691}
# I0401 04:58:52.212354 138583278085952 model_lib_v2.py:705] Step 9400 per-step time 3.463s
# I0401 04:58:52.213101 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.36346835,
#  'Loss/localization_loss': 0.29134566,
#  'Loss/regularization_loss': 0.026738703,
#  'Loss/total_loss': 0.6815527,
#  'learning_rate': 0.079893865}
# I0401 05:04:44.661120 138583278085952 model_lib_v2.py:705] Step 9500 per-step time 3.524s
# I0401 05:04:44.662260 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.5846262,
#  'Loss/localization_loss': 0.3808999,
#  'Loss/regularization_loss': 0.02680181,
#  'Loss/total_loss': 0.9923279,
#  'learning_rate': 0.079890765}
# I0401 05:10:32.066692 138583278085952 model_lib_v2.py:705] Step 9600 per-step time 3.474s
# I0401 05:10:32.067740 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.6476203,
#  'Loss/localization_loss': 0.40388513,
#  'Loss/regularization_loss': 0.0269018,
#  'Loss/total_loss': 1.0784073,
#  'learning_rate': 0.07988763}
# I0401 05:16:20.522495 138583278085952 model_lib_v2.py:705] Step 9700 per-step time 3.485s
# I0401 05:16:20.523304 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.4221931,
#  'Loss/localization_loss': 0.33435476,
#  'Loss/regularization_loss': 0.026989006,
#  'Loss/total_loss': 0.7835369,
#  'learning_rate': 0.07988444}
# I0401 05:22:21.128320 138583278085952 model_lib_v2.py:705] Step 9800 per-step time 3.606s
# I0401 05:22:21.129605 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.51491696,
#  'Loss/localization_loss': 0.19479062,
#  'Loss/regularization_loss': 0.027355012,
#  'Loss/total_loss': 0.7370626,
#  'learning_rate': 0.079881206}
# I0401 05:28:12.476889 138583278085952 model_lib_v2.py:705] Step 9900 per-step time 3.513s
# I0401 05:28:12.477781 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.47169635,
#  'Loss/localization_loss': 0.34141636,
#  'Loss/regularization_loss': 0.027448803,
#  'Loss/total_loss': 0.8405615,
#  'learning_rate': 0.07987793}
# I0401 05:34:04.760194 138583278085952 model_lib_v2.py:705] Step 10000 per-step time 3.523s
# I0401 05:34:04.761002 138583278085952 model_lib_v2.py:708] {'Loss/classification_loss': 0.2968889,
#  'Loss/localization_loss': 0.14797689,
#  'Loss/regularization_loss': 0.027509946,
#  'Loss/total_loss': 0.47237572,
#  'learning_rate': 0.07987461}

# %%
os.getcwd()
# Out:
# '/kaggle/working/models/research'

# %%
# !python /kaggle/working/models/research/object_detection/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path /kaggle/working/models/research/object_detection/configs/tf2/modified_effdet_d0.config \
    --trained_checkpoint_dir /kaggle/working/efficientdet_d0_train \
    --output_directory /kaggle/working/exported_efficientdet_d0
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/models/research/object_detection/exporter_main_v2.py", line 104, in <module>
#     from object_detection import exporter_lib_v2
#   File "/opt/conda/lib/python3.10/site-packages/object_detection/exporter_lib_v2.py", line 21, in <module>
#     from object_detection.builders import model_builder
#   File "/opt/conda/lib/python3.10/site-packages/object_detection/builders/model_builder.py", line 26, in <module>
#     from object_detection.builders import hyperparams_builder
#   File "/opt/conda/lib/python3.10/site-packages/object_detection/builders/hyperparams_builder.py", line 27, in <module>
#     from object_detection.core import freezable_sync_batch_norm
#   File "/opt/conda/lib/python3.10/site-packages/object_detection/core/freezable_sync_batch_norm.py", line 20, in <module>
#     class FreezableSyncBatchNorm(tf.keras.layers.experimental.SyncBatchNormalization
# AttributeError: module 'keras._tf_keras.keras.layers' has no attribute 'experimental'

# %%
# !tar -czvf efficientdet_d0_train.tar.gz /kaggle/working/efficientdet_d0_train
# Out:
# tar: Removing leading `/' from member names
# /kaggle/working/efficientdet_d0_train/
# /kaggle/working/efficientdet_d0_train/ckpt-11.index
# /kaggle/working/efficientdet_d0_train/ckpt-8.index
# /kaggle/working/efficientdet_d0_train/ckpt-7.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/ckpt-6.index
# /kaggle/working/efficientdet_d0_train/ckpt-12.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/ckpt-9.index
# /kaggle/working/efficientdet_d0_train/ckpt-10.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/train/
# /kaggle/working/efficientdet_d0_train/train/events.out.tfevents.1711914516.9580c5ee9a3b.638.0.v2
# /kaggle/working/efficientdet_d0_train/train/events.out.tfevents.1711913437.9580c5ee9a3b.164.0.v2
# /kaggle/working/efficientdet_d0_train/ckpt-10.index
# /kaggle/working/efficientdet_d0_train/ckpt-6.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/ckpt-11.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/ckpt-8.data-00000-of-00001
# /kaggle/working/efficientdet_d0_train/ckpt-7.index
# /kaggle/working/efficientdet_d0_train/ckpt-12.index
# /kaggle/working/efficientdet_d0_train/checkpoint
# /kaggle/working/efficientdet_d0_train/ckpt-9.data-00000-of-00001
